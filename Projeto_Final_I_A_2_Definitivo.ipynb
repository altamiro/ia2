# %% [markdown]
# <h1>Flowers Recognition - Convolucional Neural Network (CNN)</h1>

# %% [markdown]
# O propósito deste trabalho é apresentar modelos de Redes Neurais Convolucionais (CNN) utilizados para fazer o reconhecimento de imagens de flores.
#
# Não há um problema específico a ser solucionado, servindo apenas de demonstração do potencial do uso dos recursos computacionais para reconhecimento de imagens, sendo que os modelos apresentados podem ser adaptados para outros contextos e outras bases de dados.
#
# Cada etapa da construção dos modelos será detalhada abaixo e os resultados de <b>acurácia</b> serão apresentados graficamente a cada execução.
#
# Consideramos como dificuldades para realização do trabalho a baixa disponibilidade de imagens rotuladas para as espécies de flores que estamos estudando.
#
# Ainda assim, consideramos a limitação dos recursos computacionais próprios (tendo em vista que fizemos os treinamentos nas máquinas pessoais) para processamento. Ainda que seja um trabalho essencialmente acadêmico, o tempo de execução dos treinamentos e as falhas no processamento por exaustão de recursos (leia-se memória RAM) tornaram o caminho um pouco mais árduo para se conseguir uma conclusão.

# %% [markdown]
# <h2>Etapa 1 - Importação de bibliotecas</h2>

# %% [markdown]
# Keras é uma API de redes neuras de alto nível para rodar em cima do TensorFlow(Ecossistema open-source para desenvolvimento de aprendizado de máquina - Machine Learning), com foco em permitir a experimentação rápida.
#
# Usamos o bibliotecas de preprocessamento de imagens e de Machine Learning, estas últimas voltadas para as Redes Neurais Convolucionais (CNN)

# %%
#Preprocessamento de imagem
from keras.preprocessing.image import ImageDataGenerator

#Bibliotecas para Machine Learning
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adamax,Adadelta
from keras.utils import to_categorical

# Bibliotecas específicas para CNN
from keras.layers import Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Utilizamos a bibliteoteca scikit-learn para seleção da base de treinamento e teste

# %%
#model selection
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Utilizamos também bibliotecas para manipulação das imagens

# %%
import cv2                    
from tqdm import tqdm
import os 
import random as rn

# %% [markdown]
# Adicionalmente fizemos uso das bibliotecas Matplotlib e Seaborn para geração dos gráficos de desempenho dos modelos

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# %%
# %matplotlib inline 
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

# %% [markdown]
# <h2>Etapa 2 - Preparação dos dados</h2>

# %% [markdown]
# Apontamento da base de dados

# %%
X=[]
Z=[]
IMG_SIZE=150
FLOWER_DAISY_DIR='flowers/daisy'
FLOWER_SUNFLOWER_DIR='flowers/sunflower'
FLOWER_TULIP_DIR='flowers/tulip'
FLOWER_DANDI_DIR='flowers/dandelion'
FLOWER_ROSE_DIR='flowers/rose'

# %% [markdown]
# Construção da base de treinamento e validação

# %%
def assign_label(img,flower_type):
    return flower_type

def make_train_data(flower_type,DIR):
    for img in tqdm(os.listdir(DIR)):
        label=assign_label(img,flower_type)
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
        
        X.append(np.array(img))
        Z.append(str(label))

# %% [markdown]
# Carregamento das bases com 5 espécies de flores (5 classes)

# %%
make_train_data('Daisy',FLOWER_DAISY_DIR)
make_train_data('Sunflower',FLOWER_SUNFLOWER_DIR)
make_train_data('Tulip',FLOWER_TULIP_DIR)
make_train_data('Dandelion',FLOWER_DANDI_DIR)
make_train_data('Rose',FLOWER_ROSE_DIR)
# Out:
# 100%|██████████| 792/792 [00:04<00:00, 196.35it/s]
# 100%|██████████| 760/760 [00:03<00:00, 238.21it/s]
# 100%|██████████| 1020/1020 [00:04<00:00, 215.72it/s]
# 100%|██████████| 1062/1062 [00:04<00:00, 254.74it/s]
# 100%|██████████| 876/876 [00:04<00:00, 186.92it/s]

# %% [markdown]
# Visualização randômica de algumas imagens

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=rn.randint(0,len(Z))
        ax[i,j].imshow(X[l])
        ax[i,j].set_title('Flower: '+Z[l])
        
plt.tight_layout()

# %% [markdown]
# Separação em conjunto de treinamento e validação

# %%
le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,5)
X=np.array(X)
X=X/255

x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

np.random.seed(42)
rn.seed(42)
tf.set_random_seed(42)

# %% [markdown]
# Aumento da base de dados com o objetivo de evitar <b>overfitting</b>.
#
# Utilizando a biblioteca de preprocessamento de imagens do Keras, construímos uma função que faz a geração de novas imagens a partir das imagens contidas na base de dados de treinamento, em tempo de execução. Estas novas imagens são geradas aumentando as amostras da base de treinamento por meio de várias transformações aleatórias que geram imagens de aparência confiável em cada execução do modelo, fazendo com que a rede não veja a mesma imagem mais de uma vez.

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images

datagen.fit(x_train)

# %% [markdown]
# Definição do tamanho de cada lote de análise e da quantidade de épocas de treinamento

# %%
batch_size=128
epochs=5

# %% [markdown]
# <h2> Etapa 3 - Definição, compilação, resumo, treinamento e resultado dos modelos</h2>

# %% [markdown]
# <h4> Definição do modelo</h4>
#
# Utilizamos o modelo Keras Sequential, que é uma pilha linear de camadas, onde é passada uma lista de camadas para o construtor.
#
# Definimos 4 modelos com pequenas variações de características para fins de comparação.
#
# As camadas foram definidas com a biblioteca Keras Conv2D(convolução espacial sobre imagens). Nas Redes Neurais Convolucionais, as saídas de uma camada são as entradas da próxima camada da lista. Cada camada pode ter diferentes números de filtros e núcleos que são utilizados, de forma resumida, para extrair as características das imagens.
#
# No presente caso, estamos utilizando 4 camadas convolucionais.
#
# Após passar pelas camadas convolucionais, os dados são aplainados (Flatten), ou seja, convertidos em um vetor e entram numa camada densa de 256 classes (Dense) onde são totalmente conectados. A opção pelas 256 classes nestes modelos se deu por não haver melhora significativa dos resultados em que pese ter havido um aumento no consumo de recursos de processamento.
#
# Para um melhor desempenho do modelo é feita a normalização da saída da camada densa (BatchNormalization) e em seguida os dados entram numa nova camada densa com o 5 classes (conforme base de dados rotulada)
#
# Para que o modelo seja compilado é necessário que se passe um otimizador (Optimazer). Cada otimizador tem parâmetros diferentes que melhor se adaptam ao problema a ser solucionado, portanto, a escolha do otimizador vai influenciar nos resultados obtidos pelo modelo.
#
# Para este trabalho optamos pela utilização de 2 otimizados para fins de comparação. Os otimizadores utilizados foram o <b>Adamax</b> e o <b>Adadelta</b>, ambos com seus parâmetros definidos nos valores padrão.
#
# O Adamax é uma variação do otimizador Adam e utiliza a otimização baseada em um gradiente estocástico, que é aquele cujo o estado é indeterminado, com origem em eventos aleatórios.
#
# O Adadelta é uma extensão mais robusta do Adagrad que adapta as taxas de aprendizado com base em uma janela móvel de atualizações do gradiente, em vez de acumular todos os gradientes.
#
# Por fim, ainda para fins de comparação acrescentamos em 2 modelos (um de cada otimizador) a layer Dropout de <b>0.5</b> na entrada da primeira camada densa com o objetivo de previnir o overfitting.

# %% [markdown]
# <h3>ADAMAX sem dropout</h3>

# %%
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',activation ='relu', input_shape = (150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
 
model.add(Conv2D(filters =96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(256, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dense(5, activation = 'softmax'))

model.compile(optimizer=Adamax(lr=0.002),loss='categorical_crossentropy',metrics=['accuracy'])

model.summary()

History = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test),
                              steps_per_epoch=x_train.shape[0] // batch_size)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      2432
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 37, 37, 96)        55392
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 18, 18, 96)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 18, 18, 96)        83040
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 9, 9, 96)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7776)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               1990912
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 2,152,581
# Trainable params: 2,152,069
# Non-trainable params: 512
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/5
# 26/26 [==============================] - 19s 733ms/step - loss: 1.3091 - acc: 0.4561 - val_loss: 3.2488 - val_acc: 0.2926
# Epoch 2/5
# 26/26 [==============================] - 16s 608ms/step - loss: 1.0872 - acc: 0.5640 - val_loss: 1.1604 - val_acc: 0.5390
# Epoch 3/5
# 26/26 [==============================] - 17s 637ms/step - loss: 1.0186 - acc: 0.5950 - val_loss: 0.9431 - val_acc: 0.6215
# Epoch 4/5
# 26/26 [==============================] - 16s 609ms/step - loss: 0.9460 - acc: 0.6382 - val_loss: 1.0132 - val_acc: 0.6028
# Epoch 5/5
# 26/26 [==============================] - 15s 577ms/step - loss: 0.8850 - acc: 0.6541 - val_loss: 1.0289 - val_acc: 0.5691

# %% [markdown]
# <h4>Gráficos para avaliação do desempenho do modelo </h4>
#
# Apresentam a <b>perda</b> (loss) e a <b>acurácia</b> (accuracy) apuradas no treinamento e validação

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

plt.plot(History.history['acc'])
plt.plot(History.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# <h3>ADAMAX com dropout</h3>

# %%
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',activation ='relu', input_shape = (150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
 
model.add(Conv2D(filters =96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(256, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dense(5, activation = 'softmax'))

model.compile(optimizer=Adamax(lr=0.002),loss='categorical_crossentropy',metrics=['accuracy'])

model.summary()

History = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test),
                              steps_per_epoch=x_train.shape[0] // batch_size)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 150, 150, 32)      2432
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 37, 37, 96)        55392
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 18, 18, 96)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 18, 18, 96)        83040
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 9, 9, 96)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 7776)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7776)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               1990912
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 2,152,581
# Trainable params: 2,152,069
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/5
# 26/26 [==============================] - ETA: 1:44 - loss: 1.6088 - acc: 0.234 - ETA: 1:04 - loss: 1.6064 - acc: 0.218 - ETA: 50s - loss: 1.6049 - acc: 0.234 - ETA: 42s - loss: 1.6065 - acc: 0.23 - ETA: 37s - loss: 1.6072 - acc: 0.23 - ETA: 33s - loss: 1.6153 - acc: 0.22 - ETA: 30s - loss: 1.6104 - acc: 0.23 - ETA: 28s - loss: 1.6100 - acc: 0.22 - ETA: 25s - loss: 1.6103 - acc: 0.22 - ETA: 23s - loss: 1.6094 - acc: 0.23 - ETA: 21s - loss: 1.6063 - acc: 0.23 - ETA: 20s - loss: 1.6068 - acc: 0.23 - ETA: 18s - loss: 1.6053 - acc: 0.24 - ETA: 16s - loss: 1.6057 - acc: 0.23 - ETA: 15s - loss: 1.6042 - acc: 0.24 - ETA: 13s - loss: 1.6040 - acc: 0.24 - ETA: 12s - loss: 1.6039 - acc: 0.24 - ETA: 10s - loss: 1.6015 - acc: 0.24 - ETA: 9s - loss: 1.6007 - acc: 0.2467 - ETA: 7s - loss: 1.6010 - acc: 0.245 - ETA: 6s - loss: 1.5992 - acc: 0.247 - ETA: 5s - loss: 1.5979 - acc: 0.246 - ETA: 3s - loss: 1.5978 - acc: 0.246 - ETA: 2s - loss: 1.5966 - acc: 0.249 - ETA: 1s - loss: 1.5948 - acc: 0.252 - 38s 1s/step - loss: 1.5938 - acc: 0.2530 - val_loss: 1.5622 - val_acc: 0.2996
# Epoch 2/5
# 26/26 [==============================] - ETA: 12s - loss: 1.6381 - acc: 0.22 - ETA: 20s - loss: 1.5770 - acc: 0.25 - ETA: 21s - loss: 1.5772 - acc: 0.25 - ETA: 22s - loss: 1.5622 - acc: 0.25 - ETA: 21s - loss: 1.5573 - acc: 0.26 - ETA: 21s - loss: 1.5522 - acc: 0.27 - ETA: 20s - loss: 1.5476 - acc: 0.27 - ETA: 19s - loss: 1.5383 - acc: 0.28 - ETA: 18s - loss: 1.5379 - acc: 0.28 - ETA: 17s - loss: 1.5421 - acc: 0.28 - ETA: 16s - loss: 1.5405 - acc: 0.28 - ETA: 15s - loss: 1.5427 - acc: 0.28 - ETA: 14s - loss: 1.5392 - acc: 0.29 - ETA: 13s - loss: 1.5403 - acc: 0.29 - ETA: 12s - loss: 1.5346 - acc: 0.30 - ETA: 11s - loss: 1.5325 - acc: 0.30 - ETA: 10s - loss: 1.5305 - acc: 0.30 - ETA: 9s - loss: 1.5313 - acc: 0.3057 - ETA: 7s - loss: 1.5308 - acc: 0.304 - ETA: 6s - loss: 1.5307 - acc: 0.305 - ETA: 5s - loss: 1.5308 - acc: 0.306 - ETA: 4s - loss: 1.5280 - acc: 0.309 - ETA: 3s - loss: 1.5248 - acc: 0.316 - ETA: 2s - loss: 1.5245 - acc: 0.313 - ETA: 1s - loss: 1.5231 - acc: 0.314 - 34s 1s/step - loss: 1.5212 - acc: 0.3166 - val_loss: 1.5757 - val_acc: 0.2863
# Epoch 3/5
# 26/26 [==============================] - ETA: 29s - loss: 1.6087 - acc: 0.23 - ETA: 20s - loss: 1.5449 - acc: 0.30 - ETA: 22s - loss: 1.5260 - acc: 0.31 - ETA: 22s - loss: 1.5178 - acc: 0.31 - ETA: 21s - loss: 1.5215 - acc: 0.30 - ETA: 21s - loss: 1.5110 - acc: 0.31 - ETA: 20s - loss: 1.5109 - acc: 0.31 - ETA: 19s - loss: 1.5032 - acc: 0.32 - ETA: 18s - loss: 1.4982 - acc: 0.32 - ETA: 17s - loss: 1.5011 - acc: 0.32 - ETA: 16s - loss: 1.4984 - acc: 0.32 - ETA: 15s - loss: 1.4972 - acc: 0.32 - ETA: 14s - loss: 1.4952 - acc: 0.32 - ETA: 13s - loss: 1.4905 - acc: 0.33 - ETA: 12s - loss: 1.4915 - acc: 0.33 - ETA: 11s - loss: 1.4922 - acc: 0.33 - ETA: 10s - loss: 1.4847 - acc: 0.33 - ETA: 9s - loss: 1.4864 - acc: 0.3361 - ETA: 8s - loss: 1.4892 - acc: 0.335 - ETA: 6s - loss: 1.4880 - acc: 0.336 - ETA: 5s - loss: 1.4872 - acc: 0.337 - ETA: 4s - loss: 1.4891 - acc: 0.334 - ETA: 3s - loss: 1.4873 - acc: 0.336 - ETA: 2s - loss: 1.4858 - acc: 0.338 - ETA: 1s - loss: 1.4854 - acc: 0.340 - 34s 1s/step - loss: 1.4842 - acc: 0.3414 - val_loss: 1.5362 - val_acc: 0.3289
# Epoch 4/5
# 26/26 [==============================] - ETA: 29s - loss: 1.4330 - acc: 0.38 - ETA: 28s - loss: 1.4990 - acc: 0.32 - ETA: 21s - loss: 1.4734 - acc: 0.33 - ETA: 22s - loss: 1.4674 - acc: 0.33 - ETA: 21s - loss: 1.4625 - acc: 0.33 - ETA: 21s - loss: 1.4567 - acc: 0.33 - ETA: 20s - loss: 1.4548 - acc: 0.33 - ETA: 19s - loss: 1.4422 - acc: 0.34 - ETA: 18s - loss: 1.4402 - acc: 0.35 - ETA: 17s - loss: 1.4437 - acc: 0.34 - ETA: 16s - loss: 1.4461 - acc: 0.34 - ETA: 15s - loss: 1.4518 - acc: 0.34 - ETA: 14s - loss: 1.4546 - acc: 0.34 - ETA: 13s - loss: 1.4546 - acc: 0.34 - ETA: 12s - loss: 1.4518 - acc: 0.34 - ETA: 11s - loss: 1.4586 - acc: 0.34 - ETA: 10s - loss: 1.4564 - acc: 0.34 - ETA: 9s - loss: 1.4590 - acc: 0.3478 - ETA: 7s - loss: 1.4580 - acc: 0.348 - ETA: 6s - loss: 1.4599 - acc: 0.349 - ETA: 5s - loss: 1.4634 - acc: 0.349 - ETA: 4s - loss: 1.4613 - acc: 0.351 - ETA: 3s - loss: 1.4593 - acc: 0.352 - ETA: 2s - loss: 1.4596 - acc: 0.353 - ETA: 1s - loss: 1.4618 - acc: 0.350 - 34s 1s/step - loss: 1.4616 - acc: 0.3502 - val_loss: 1.4971 - val_acc: 0.3112
# Epoch 5/5
# 26/26 [==============================] - ETA: 29s - loss: 1.4189 - acc: 0.34 - ETA: 28s - loss: 1.4090 - acc: 0.38 - ETA: 27s - loss: 1.4024 - acc: 0.39 - ETA: 22s - loss: 1.4225 - acc: 0.39 - ETA: 22s - loss: 1.4184 - acc: 0.39 - ETA: 21s - loss: 1.4246 - acc: 0.39 - ETA: 20s - loss: 1.4185 - acc: 0.39 - ETA: 19s - loss: 1.4093 - acc: 0.39 - ETA: 18s - loss: 1.4098 - acc: 0.39 - ETA: 17s - loss: 1.4141 - acc: 0.39 - ETA: 16s - loss: 1.4108 - acc: 0.39 - ETA: 15s - loss: 1.4160 - acc: 0.39 - ETA: 14s - loss: 1.4220 - acc: 0.39 - ETA: 13s - loss: 1.4225 - acc: 0.39 - ETA: 12s - loss: 1.4290 - acc: 0.38 - ETA: 11s - loss: 1.4263 - acc: 0.38 - ETA: 10s - loss: 1.4260 - acc: 0.38 - ETA: 9s - loss: 1.4265 - acc: 0.3865 - ETA: 7s - loss: 1.4293 - acc: 0.383 - ETA: 6s - loss: 1.4288 - acc: 0.381 - ETA: 5s - loss: 1.4274 - acc: 0.381 - ETA: 4s - loss: 1.4269 - acc: 0.383 - ETA: 3s - loss: 1.4263 - acc: 0.382 - ETA: 2s - loss: 1.4266 - acc: 0.382 - ETA: 1s - loss: 1.4252 - acc: 0.383 - 34s 1s/step - loss: 1.4280 - acc: 0.3823 - val_loss: 1.4429 - val_acc: 0.3493

# %% [markdown]
# <h4>Gráficos para avaliação do desempenho do modelo </h4>
#
# Apresentam a <b>perda</b> (loss) e a <b>acurácia</b> (accuracy) apuradas no treinamento e validação

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

plt.plot(History.history['acc'])
plt.plot(History.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# <h3>ADADELTA sem dropout</h3>

# %%
#ADADELTA sem dropout
# # modelling starts using a CNN.

model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',activation ='relu', input_shape = (150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
 
model.add(Conv2D(filters =96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(256, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dense(5, activation = 'softmax'))

model.compile(optimizer=Adadelta(lr=1.0),loss='categorical_crossentropy',metrics=['accuracy'])

model.summary()

History = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test), 
                              steps_per_epoch=x_train.shape[0] // batch_size)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 150, 150, 32)      2432
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 37, 37, 96)        55392
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 18, 18, 96)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 18, 18, 96)        83040
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 9, 9, 96)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 7776)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               1990912
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 2,152,581
# Trainable params: 2,152,069
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/5
# 26/26 [==============================] - ETA: 1:17 - loss: 1.6093 - acc: 0.210 - ETA: 51s - loss: 1.6071 - acc: 0.273 - ETA: 41s - loss: 1.6065 - acc: 0.27 - ETA: 36s - loss: 1.6058 - acc: 0.27 - ETA: 33s - loss: 1.6058 - acc: 0.26 - ETA: 30s - loss: 1.6057 - acc: 0.26 - ETA: 27s - loss: 1.6054 - acc: 0.26 - ETA: 25s - loss: 1.6044 - acc: 0.26 - ETA: 23s - loss: 1.6028 - acc: 0.26 - ETA: 22s - loss: 1.6016 - acc: 0.26 - ETA: 20s - loss: 1.5997 - acc: 0.25 - ETA: 18s - loss: 1.5986 - acc: 0.26 - ETA: 17s - loss: 1.5987 - acc: 0.26 - ETA: 15s - loss: 1.5976 - acc: 0.26 - ETA: 14s - loss: 1.5935 - acc: 0.27 - ETA: 13s - loss: 1.5908 - acc: 0.27 - ETA: 11s - loss: 1.5881 - acc: 0.27 - ETA: 10s - loss: 1.5848 - acc: 0.27 - ETA: 9s - loss: 1.5804 - acc: 0.2825 - ETA: 7s - loss: 1.5780 - acc: 0.284 - ETA: 6s - loss: 1.5747 - acc: 0.284 - ETA: 5s - loss: 1.5677 - acc: 0.288 - ETA: 3s - loss: 1.5614 - acc: 0.293 - ETA: 2s - loss: 1.5568 - acc: 0.295 - ETA: 1s - loss: 1.5498 - acc: 0.300 - 37s 1s/step - loss: 1.5415 - acc: 0.3029 - val_loss: 12.4601 - val_acc: 0.2270
# Epoch 2/5
# 26/26 [==============================] - ETA: 12s - loss: 1.3995 - acc: 0.42 - ETA: 20s - loss: 1.3844 - acc: 0.41 - ETA: 22s - loss: 1.4430 - acc: 0.41 - ETA: 22s - loss: 1.4329 - acc: 0.39 - ETA: 22s - loss: 1.4121 - acc: 0.39 - ETA: 21s - loss: 1.3983 - acc: 0.39 - ETA: 20s - loss: 1.3911 - acc: 0.40 - ETA: 19s - loss: 1.3855 - acc: 0.41 - ETA: 18s - loss: 1.3836 - acc: 0.40 - ETA: 17s - loss: 1.3861 - acc: 0.41 - ETA: 16s - loss: 1.3834 - acc: 0.41 - ETA: 15s - loss: 1.3718 - acc: 0.41 - ETA: 14s - loss: 1.3609 - acc: 0.42 - ETA: 13s - loss: 1.3616 - acc: 0.42 - ETA: 12s - loss: 1.3562 - acc: 0.42 - ETA: 11s - loss: 1.3526 - acc: 0.42 - ETA: 10s - loss: 1.3477 - acc: 0.43 - ETA: 9s - loss: 1.3441 - acc: 0.4325 - ETA: 8s - loss: 1.3435 - acc: 0.432 - ETA: 6s - loss: 1.3433 - acc: 0.433 - ETA: 5s - loss: 1.3445 - acc: 0.432 - ETA: 4s - loss: 1.3439 - acc: 0.431 - ETA: 3s - loss: 1.3365 - acc: 0.433 - ETA: 2s - loss: 1.3362 - acc: 0.431 - ETA: 1s - loss: 1.3338 - acc: 0.430 - 35s 1s/step - loss: 1.3351 - acc: 0.4286 - val_loss: 9.9979 - val_acc: 0.1924
# Epoch 3/5
# 26/26 [==============================] - ETA: 29s - loss: 1.2222 - acc: 0.47 - ETA: 20s - loss: 1.2945 - acc: 0.43 - ETA: 22s - loss: 1.2887 - acc: 0.41 - ETA: 22s - loss: 1.2824 - acc: 0.42 - ETA: 22s - loss: 1.2741 - acc: 0.42 - ETA: 21s - loss: 1.2774 - acc: 0.42 - ETA: 20s - loss: 1.2786 - acc: 0.42 - ETA: 19s - loss: 1.2815 - acc: 0.42 - ETA: 18s - loss: 1.2868 - acc: 0.41 - ETA: 17s - loss: 1.2846 - acc: 0.41 - ETA: 16s - loss: 1.2965 - acc: 0.40 - ETA: 15s - loss: 1.3020 - acc: 0.41 - ETA: 14s - loss: 1.3042 - acc: 0.41 - ETA: 13s - loss: 1.3013 - acc: 0.42 - ETA: 12s - loss: 1.2934 - acc: 0.42 - ETA: 11s - loss: 1.2879 - acc: 0.42 - ETA: 10s - loss: 1.2810 - acc: 0.43 - ETA: 9s - loss: 1.2788 - acc: 0.4339 - ETA: 8s - loss: 1.2756 - acc: 0.433 - ETA: 6s - loss: 1.2744 - acc: 0.432 - ETA: 5s - loss: 1.2656 - acc: 0.437 - ETA: 4s - loss: 1.2643 - acc: 0.437 - ETA: 3s - loss: 1.2628 - acc: 0.436 - ETA: 2s - loss: 1.2603 - acc: 0.438 - ETA: 1s - loss: 1.2612 - acc: 0.437 - 35s 1s/step - loss: 1.2598 - acc: 0.4399 - val_loss: 8.2624 - val_acc: 0.1924
# Epoch 4/5
# 26/26 [==============================] - ETA: 29s - loss: 1.2688 - acc: 0.47 - ETA: 28s - loss: 1.2895 - acc: 0.42 - ETA: 22s - loss: 1.2614 - acc: 0.45 - ETA: 22s - loss: 1.2660 - acc: 0.46 - ETA: 22s - loss: 1.3112 - acc: 0.44 - ETA: 21s - loss: 1.3108 - acc: 0.44 - ETA: 20s - loss: 1.2953 - acc: 0.45 - ETA: 19s - loss: 1.2773 - acc: 0.45 - ETA: 18s - loss: 1.2726 - acc: 0.45 - ETA: 17s - loss: 1.2712 - acc: 0.45 - ETA: 16s - loss: 1.2716 - acc: 0.45 - ETA: 15s - loss: 1.2709 - acc: 0.45 - ETA: 14s - loss: 1.2706 - acc: 0.45 - ETA: 13s - loss: 1.2651 - acc: 0.45 - ETA: 12s - loss: 1.2670 - acc: 0.45 - ETA: 11s - loss: 1.2657 - acc: 0.45 - ETA: 10s - loss: 1.2612 - acc: 0.45 - ETA: 9s - loss: 1.2549 - acc: 0.4585 - ETA: 8s - loss: 1.2580 - acc: 0.457 - ETA: 6s - loss: 1.2564 - acc: 0.456 - ETA: 5s - loss: 1.2559 - acc: 0.458 - ETA: 4s - loss: 1.2471 - acc: 0.465 - ETA: 3s - loss: 1.2423 - acc: 0.467 - ETA: 2s - loss: 1.2453 - acc: 0.467 - ETA: 1s - loss: 1.2452 - acc: 0.467 - 35s 1s/step - loss: 1.2451 - acc: 0.4676 - val_loss: 10.8004 - val_acc: 0.2270
# Epoch 5/5
# 26/26 [==============================] - ETA: 29s - loss: 1.2027 - acc: 0.46 - ETA: 28s - loss: 1.2169 - acc: 0.46 - ETA: 27s - loss: 1.2117 - acc: 0.46 - ETA: 22s - loss: 1.2105 - acc: 0.45 - ETA: 22s - loss: 1.2098 - acc: 0.46 - ETA: 21s - loss: 1.2021 - acc: 0.47 - ETA: 20s - loss: 1.1993 - acc: 0.48 - ETA: 19s - loss: 1.2041 - acc: 0.48 - ETA: 18s - loss: 1.2046 - acc: 0.47 - ETA: 17s - loss: 1.2137 - acc: 0.48 - ETA: 16s - loss: 1.2119 - acc: 0.48 - ETA: 15s - loss: 1.2044 - acc: 0.48 - ETA: 14s - loss: 1.2027 - acc: 0.48 - ETA: 13s - loss: 1.2089 - acc: 0.48 - ETA: 12s - loss: 1.2094 - acc: 0.48 - ETA: 11s - loss: 1.2063 - acc: 0.48 - ETA: 10s - loss: 1.2087 - acc: 0.48 - ETA: 9s - loss: 1.2084 - acc: 0.4855 - ETA: 8s - loss: 1.2094 - acc: 0.483 - ETA: 6s - loss: 1.2057 - acc: 0.486 - ETA: 5s - loss: 1.1987 - acc: 0.492 - ETA: 4s - loss: 1.1955 - acc: 0.496 - ETA: 3s - loss: 1.1963 - acc: 0.497 - ETA: 2s - loss: 1.1951 - acc: 0.497 - ETA: 1s - loss: 1.1963 - acc: 0.496 - 35s 1s/step - loss: 1.1937 - acc: 0.4984 - val_loss: 11.1848 - val_acc: 0.2270

# %% [markdown]
# <h4>Gráficos para avaliação do desempenho do modelo </h4>
#
# Apresentam a <b>perda</b> (loss) e a <b>acurácia</b> (accuracy) apuradas no treinamento e validação

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

plt.plot(History.history['acc'])
plt.plot(History.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# <h3>ADADELTA com dropout</h3>

# %%
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',activation ='relu', input_shape = (150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
 

model.add(Conv2D(filters =96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(256, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dense(5, activation = 'softmax'))

model.compile(optimizer=Adadelta(lr=1.0),loss='categorical_crossentropy',metrics=['accuracy'])

model.summary()

History = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test),
                              steps_per_epoch=x_train.shape[0] // batch_size)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 150, 150, 32)      2432
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 37, 37, 96)        55392
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 18, 18, 96)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 18, 18, 96)        83040
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 9, 9, 96)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 7776)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7776)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               1990912
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 2,152,581
# Trainable params: 2,152,069
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/5
# 26/26 [==============================] - ETA: 1:13 - loss: 1.9123 - acc: 0.218 - ETA: 49s - loss: 2.0152 - acc: 0.242 - ETA: 41s - loss: 1.9032 - acc: 0.27 - ETA: 36s - loss: 1.8713 - acc: 0.27 - ETA: 32s - loss: 1.8094 - acc: 0.30 - ETA: 29s - loss: 1.7789 - acc: 0.31 - ETA: 27s - loss: 1.7417 - acc: 0.32 - ETA: 25s - loss: 1.6833 - acc: 0.34 - ETA: 23s - loss: 1.7035 - acc: 0.34 - ETA: 21s - loss: 1.7089 - acc: 0.34 - ETA: 20s - loss: 1.6961 - acc: 0.34 - ETA: 18s - loss: 1.6788 - acc: 0.35 - ETA: 17s - loss: 1.6549 - acc: 0.35 - ETA: 15s - loss: 1.6378 - acc: 0.36 - ETA: 14s - loss: 1.6348 - acc: 0.36 - ETA: 13s - loss: 1.6123 - acc: 0.37 - ETA: 11s - loss: 1.6002 - acc: 0.37 - ETA: 10s - loss: 1.5890 - acc: 0.38 - ETA: 9s - loss: 1.5702 - acc: 0.3861 - ETA: 7s - loss: 1.5680 - acc: 0.390 - ETA: 6s - loss: 1.5524 - acc: 0.393 - ETA: 5s - loss: 1.5358 - acc: 0.400 - ETA: 3s - loss: 1.5267 - acc: 0.404 - ETA: 2s - loss: 1.5155 - acc: 0.407 - ETA: 1s - loss: 1.4975 - acc: 0.415 - 37s 1s/step - loss: 1.4885 - acc: 0.4216 - val_loss: 1.2486 - val_acc: 0.5133
# Epoch 2/5
# 26/26 [==============================] - ETA: 13s - loss: 1.2627 - acc: 0.53 - ETA: 20s - loss: 1.2017 - acc: 0.54 - ETA: 22s - loss: 1.1839 - acc: 0.53 - ETA: 22s - loss: 1.1775 - acc: 0.53 - ETA: 22s - loss: 1.1756 - acc: 0.53 - ETA: 21s - loss: 1.2061 - acc: 0.51 - ETA: 20s - loss: 1.2135 - acc: 0.51 - ETA: 19s - loss: 1.2019 - acc: 0.51 - ETA: 18s - loss: 1.1975 - acc: 0.51 - ETA: 17s - loss: 1.2041 - acc: 0.51 - ETA: 16s - loss: 1.2033 - acc: 0.51 - ETA: 15s - loss: 1.2076 - acc: 0.51 - ETA: 14s - loss: 1.2037 - acc: 0.51 - ETA: 13s - loss: 1.1942 - acc: 0.51 - ETA: 12s - loss: 1.1872 - acc: 0.51 - ETA: 11s - loss: 1.1819 - acc: 0.51 - ETA: 10s - loss: 1.1779 - acc: 0.51 - ETA: 9s - loss: 1.1790 - acc: 0.5177 - ETA: 8s - loss: 1.1787 - acc: 0.519 - ETA: 6s - loss: 1.1801 - acc: 0.517 - ETA: 5s - loss: 1.1823 - acc: 0.514 - ETA: 4s - loss: 1.1790 - acc: 0.515 - ETA: 3s - loss: 1.1757 - acc: 0.516 - ETA: 2s - loss: 1.1791 - acc: 0.515 - ETA: 1s - loss: 1.1790 - acc: 0.514 - 35s 1s/step - loss: 1.1771 - acc: 0.5161 - val_loss: 1.1451 - val_acc: 0.5204
# Epoch 3/5
# 26/26 [==============================] - ETA: 29s - loss: 1.2811 - acc: 0.45 - ETA: 20s - loss: 1.1872 - acc: 0.48 - ETA: 22s - loss: 1.1676 - acc: 0.50 - ETA: 22s - loss: 1.1618 - acc: 0.51 - ETA: 22s - loss: 1.1501 - acc: 0.51 - ETA: 21s - loss: 1.1495 - acc: 0.52 - ETA: 20s - loss: 1.1416 - acc: 0.52 - ETA: 19s - loss: 1.1535 - acc: 0.52 - ETA: 18s - loss: 1.1464 - acc: 0.52 - ETA: 17s - loss: 1.1438 - acc: 0.52 - ETA: 16s - loss: 1.1458 - acc: 0.52 - ETA: 15s - loss: 1.1487 - acc: 0.52 - ETA: 14s - loss: 1.1494 - acc: 0.52 - ETA: 13s - loss: 1.1338 - acc: 0.53 - ETA: 12s - loss: 1.1187 - acc: 0.53 - ETA: 11s - loss: 1.1093 - acc: 0.54 - ETA: 10s - loss: 1.1034 - acc: 0.55 - ETA: 9s - loss: 1.1062 - acc: 0.5540 - ETA: 8s - loss: 1.1147 - acc: 0.551 - ETA: 6s - loss: 1.1224 - acc: 0.546 - ETA: 5s - loss: 1.1221 - acc: 0.544 - ETA: 4s - loss: 1.1272 - acc: 0.541 - ETA: 3s - loss: 1.1270 - acc: 0.539 - ETA: 2s - loss: 1.1217 - acc: 0.541 - ETA: 1s - loss: 1.1189 - acc: 0.544 - 35s 1s/step - loss: 1.1118 - acc: 0.5488 - val_loss: 1.4495 - val_acc: 0.5541
# Epoch 4/5
# 26/26 [==============================] - ETA: 29s - loss: 1.0805 - acc: 0.60 - ETA: 28s - loss: 1.1876 - acc: 0.54 - ETA: 22s - loss: 1.2008 - acc: 0.55 - ETA: 22s - loss: 1.1720 - acc: 0.55 - ETA: 22s - loss: 1.1781 - acc: 0.54 - ETA: 21s - loss: 1.1536 - acc: 0.55 - ETA: 20s - loss: 1.1503 - acc: 0.54 - ETA: 19s - loss: 1.1475 - acc: 0.54 - ETA: 19s - loss: 1.1329 - acc: 0.55 - ETA: 18s - loss: 1.1294 - acc: 0.55 - ETA: 16s - loss: 1.1171 - acc: 0.56 - ETA: 15s - loss: 1.1101 - acc: 0.56 - ETA: 14s - loss: 1.1146 - acc: 0.56 - ETA: 13s - loss: 1.1111 - acc: 0.56 - ETA: 12s - loss: 1.1016 - acc: 0.57 - ETA: 11s - loss: 1.0981 - acc: 0.57 - ETA: 10s - loss: 1.0907 - acc: 0.57 - ETA: 9s - loss: 1.0931 - acc: 0.5744 - ETA: 8s - loss: 1.0902 - acc: 0.574 - ETA: 6s - loss: 1.0881 - acc: 0.576 - ETA: 5s - loss: 1.0872 - acc: 0.575 - ETA: 4s - loss: 1.0803 - acc: 0.579 - ETA: 3s - loss: 1.0714 - acc: 0.582 - ETA: 2s - loss: 1.0654 - acc: 0.586 - ETA: 1s - loss: 1.0706 - acc: 0.583 - 35s 1s/step - loss: 1.0644 - acc: 0.5864 - val_loss: 1.4476 - val_acc: 0.5665
# Epoch 5/5
# 26/26 [==============================] - ETA: 29s - loss: 1.1521 - acc: 0.62 - ETA: 28s - loss: 1.0941 - acc: 0.60 - ETA: 27s - loss: 1.0433 - acc: 0.60 - ETA: 22s - loss: 1.0628 - acc: 0.59 - ETA: 22s - loss: 1.0697 - acc: 0.58 - ETA: 21s - loss: 1.0565 - acc: 0.59 - ETA: 20s - loss: 1.0326 - acc: 0.60 - ETA: 19s - loss: 1.0255 - acc: 0.60 - ETA: 19s - loss: 1.0521 - acc: 0.59 - ETA: 17s - loss: 1.0460 - acc: 0.60 - ETA: 16s - loss: 1.0311 - acc: 0.60 - ETA: 15s - loss: 1.0220 - acc: 0.60 - ETA: 14s - loss: 1.0162 - acc: 0.60 - ETA: 13s - loss: 1.0221 - acc: 0.60 - ETA: 12s - loss: 1.0189 - acc: 0.60 - ETA: 11s - loss: 1.0227 - acc: 0.60 - ETA: 10s - loss: 1.0179 - acc: 0.60 - ETA: 9s - loss: 1.0126 - acc: 0.6090 - ETA: 8s - loss: 1.0221 - acc: 0.604 - ETA: 6s - loss: 1.0191 - acc: 0.604 - ETA: 5s - loss: 1.0166 - acc: 0.604 - ETA: 4s - loss: 1.0123 - acc: 0.606 - ETA: 3s - loss: 1.0030 - acc: 0.610 - ETA: 2s - loss: 1.0147 - acc: 0.609 - ETA: 1s - loss: 1.0150 - acc: 0.610 - 35s 1s/step - loss: 1.0111 - acc: 0.6128 - val_loss: 1.2557 - val_acc: 0.5860

# %% [markdown]
# <h4>Gráficos para avaliação do desempenho do modelo </h4>
#
# Apresentam a <b>perda</b> (loss) e a <b>acurácia</b> (accuracy) apuradas no treinamento e validação

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

plt.plot(History.history['acc'])
plt.plot(History.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# <h1>Conclusão</h1>

# %% [markdown]
# Os modelos apresentados demonstram-se satisfatórios nos índices de perda e acurácia no reconhecimento das diversas classes de flores, ainda que seja possível aprimoramentos com novos testes.
#
# Consideramos como possíveis aprimoramentos, a utilização de PCA, a modelagem de SVM's para comparação dos resultados com os modelos de CNN e fazer testes de predição com imagens não vistas nos treinamentos para apurar o quanto os modelos são capazes de identificar as flores apresentadas.
